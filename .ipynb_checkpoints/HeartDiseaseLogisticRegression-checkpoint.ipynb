# %% [markdown]
# # Heart Failure Exploratory Data Analysis

# %% [markdown]
# ### Loading CSV dataset file into the program using panda

# %%
import pandas as pd
from matplotlib import pyplot as plt 
# %matplotlib inline
import numpy as np
import seaborn as sns
import plotly.express as px

# %%
dataset_df=pd.read_csv(r"C:\Users\Asus\Downloads\datasets\archive\heart.csv")

# %% [markdown]
# ### Getting to know the variables/parameters

# %%
dataset_df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0      172              N      0.0       Up             0
# 1      156              N      1.0     Flat             1
# 2       98              N      0.0       Up             0
# 3      108              Y      1.5     Flat             1
# 4      122              N      0.0       Up             0
# ..     ...            ...      ...      ...           ...
# 913    132              N      1.2     Flat             1
# 914    141              N      3.4     Flat             1
# 915    115              Y      1.2     Flat             1
# 916    174              N      0.0     Flat             1
# 917    173              N      0.0       Up             0
#
# [918 rows x 12 columns]

# %%
print(dataset_df.shape)
# Out:
# (918, 12)

# %%
print(dataset_df.columns)
#Hello
# Out:
# Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#        'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope',
#        'HeartDisease'],
#       dtype='object')

# %%
print(dataset_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB
# None

# %% [markdown]
# ## All Parameters have 918 Non null values therefore there are no null values

# %%
print(dataset_df.describe())
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
print(dataset_df.describe().T)
# Out:
#               count        mean         std   min     25%    50%    75%    max
# Age           918.0   53.510893    9.432617  28.0   47.00   54.0   60.0   77.0
# RestingBP     918.0  132.396514   18.514154   0.0  120.00  130.0  140.0  200.0
# Cholesterol   918.0  198.799564  109.384145   0.0  173.25  223.0  267.0  603.0
# FastingBS     918.0    0.233115    0.423046   0.0    0.00    0.0    0.0    1.0
# MaxHR         918.0  136.809368   25.460334  60.0  120.00  138.0  156.0  202.0
# Oldpeak       918.0    0.887364    1.066570  -2.6    0.00    0.6    1.5    6.2
# HeartDisease  918.0    0.553377    0.497414   0.0    0.00    1.0    1.0    1.0

# %%
dataset_df[dataset_df["RestingBP"]==0]
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 449   55   M           NAP          0            0          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 449    155              N      1.5     Flat             1

# %%
dataset_df.iloc[449]
# Out:
# Age                   55
# Sex                    M
# ChestPainType        NAP
# RestingBP              0
# Cholesterol            0
# FastingBS              0
# RestingECG        Normal
# MaxHR                155
# ExerciseAngina         N
# Oldpeak              1.5
# ST_Slope            Flat
# HeartDisease           1
# Name: 449, dtype: object

# %%
dataset_df[dataset_df["RestingBP"]==0]
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 449   55   M           NAP          0            0          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 449    155              N      1.5     Flat             1

# %% [markdown]
# ## resting bp can't be zero but its just one value so replacing it with the mean value

# %%
dataset_df['RestingBP'].replace(to_replace = 0, value = dataset_df['RestingBP'].mean(), inplace=True)

# %%
dataset_df.iloc[449]
# Out:
# Age                       55
# Sex                        M
# ChestPainType            NAP
# RestingBP         132.396514
# Cholesterol                0
# FastingBS                  0
# RestingECG            Normal
# MaxHR                    155
# ExerciseAngina             N
# Oldpeak                  1.5
# ST_Slope                Flat
# HeartDisease               1
# Name: 449, dtype: object

# %% [markdown]
# ## First Few Values

# %%
print(dataset_df.head())
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA      140.0          289          0     Normal    172
# 1   49   F           NAP      160.0          180          0     Normal    156
# 2   37   M           ATA      130.0          283          0         ST     98
# 3   48   F           ASY      138.0          214          0     Normal    108
# 4   54   M           NAP      150.0          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
print(dataset_df.isnull().sum())
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %% [markdown]
# ### None of the parameters in the dataset have null value

# %% [markdown]
# # % of patients having heart diseases,

# %% [markdown]
# ### People having heart diseases

# %%
heartDiseases_df=dataset_df["HeartDisease"]

# %%
print(heartDiseases_df)
# Out:
# 0      0
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 913    1
# 914    1
# 915    1
# 916    1
# 917    0
# Name: HeartDisease, Length: 918, dtype: int64

# %%
hdtrue_df=dataset_df[dataset_df["HeartDisease"] == 1]
hdfalse_df=dataset_df[dataset_df["HeartDisease"] == 0]

# %%
print(hdtrue_df)
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 1     49   F           NAP      160.0          180          0     Normal
# 3     48   F           ASY      138.0          214          0     Normal
# 8     37   M           ASY      140.0          207          0     Normal
# 11    58   M           ATA      136.0          164          0         ST
# 13    49   M           ASY      140.0          234          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 912   57   F           ASY      140.0          241          0     Normal
# 913   45   M            TA      110.0          264          0     Normal
# 914   68   M           ASY      144.0          193          1     Normal
# 915   57   M           ASY      130.0          131          0     Normal
# 916   57   F           ATA      130.0          236          0        LVH
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 1      156              N      1.0     Flat             1
# 3      108              Y      1.5     Flat             1
# 8      130              Y      1.5     Flat             1
# 11      99              Y      2.0     Flat             1
# 13     140              Y      1.0     Flat             1
# ..     ...            ...      ...      ...           ...
# 912    123              Y      0.2     Flat             1
# 913    132              N      1.2     Flat             1
# 914    141              N      3.4     Flat             1
# 915    115              Y      1.2     Flat             1
# 916    174              N      0.0     Flat             1
#
# [508 rows x 12 columns]

# %%
totalPatients=len(heartDiseases_df)

# %%
print(totalPatients)
# Out:
# 918

# %%
heartPatients=len(hdtrue_df)

# %%
print(heartPatients)
# Out:
# 508

# %%
percentageOfHeartPatients=(heartPatients/totalPatients) * 100

# %%
print(percentageOfHeartPatients)
# Out:
# 55.33769063180828

# %%
y=[len(dataset_df[dataset_df["HeartDisease"]==1]), len(dataset_df[dataset_df["HeartDisease"]==0])]
x=['Have Heart Disease', 'Dont Have Heart Disease' ]
plt.bar(x,y)
plt.title("Heart Patients vs Non Heart Patients")
# Out:
# Text(0.5, 1.0, 'Heart Patients vs Non Heart Patients')

# %%
plt.pie([len(dataset_df[dataset_df["HeartDisease"]==1]), len(dataset_df[dataset_df["HeartDisease"]==0])])
plt.title("total patient distribution with reference to heart disease")
plt.legend(["Have Heart disease","dont have heart disease"])

# %% [markdown]
# # impact of gender

# %% [markdown]
# ## Females

# %%
females_df=dataset_df[dataset_df["Sex"]== 'F']

# %%
femaleHeartPatients=females_df[females_df["HeartDisease"]==1]

# %%
totalFemales=len(females_df)

# %%
print(totalFemales)
# Out:
# 193

# %%
femalePatients=len(femaleHeartPatients)

# %%
print(femalePatients)
# Out:
# 50

# %%
femalePercentage = femalePatients / totalFemales * 100

# %%
print(femalePercentage)
# Out:
# 25.906735751295333

# %% [markdown]
# ### around 26 percent females have heart disease

# %%
plt.pie([femalePercentage,(100-femalePercentage)])
plt.title("Heart Disease among female patients")
plt.legend(["Have Heart Disease"," Dont Have Heart Disease"])

# %% [markdown]
# ## Males

# %%
males_df=dataset_df[dataset_df["Sex"]== 'M']

# %%
maleHeartPatients=males_df[males_df["HeartDisease"]==1]

# %%
totalmales=len(males_df)

# %%
print(totalmales)
# Out:
# 725

# %%
malePatients=len(maleHeartPatients)

# %%
print(malePatients)
# Out:
# 458

# %%
malePercentage = malePatients / totalmales * 100

# %%
print(malePercentage)
# Out:
# 63.172413793103445

# %% [markdown]
# ### around 63 percent males have heart disease

# %%
plt.pie([malePercentage,(100-malePercentage)])
plt.title("Heart Disease among male patients")
plt.legend(["Have Heart Disease"," Dont Have Heart Disease"])

# %% [markdown]
# ## Male and Female Heart Failure graph

# %%
x=['overall', 'male', 'female']
y=[percentageOfHeartPatients, malePercentage, femalePercentage ]

# %%
plt.title("Percentage comparison of heart patients across genders")
plt.bar(x,y)
# Out:
# <BarContainer object of 3 artists>

# %%
plt.title("Male and Female Heart Patients in the hospital")
plt.pie([malePatients, femalePatients], labels = ['Male','Female'])
# Out:
# ([<matplotlib.patches.Wedge at 0x21b257a0790>,
#   <matplotlib.patches.Wedge at 0x21b257a0c10>],
#  [Text(-1.0478310548310048, 0.33473882435675717, 'Male'),
#   Text(1.0478310391607484, -0.3347388734092687, 'Female')])

# %% [markdown]
# ## Male percentage of heart disease is considerably higher than female percentage

# %% [markdown]
# # impact of age

# %%
plt.hist(hdtrue_df["Age"], bins = 30,ec ='red', linestyle='dashed' )
plt.title("Heart disease across age")
# Out:
# Text(0.5, 1.0, 'Heart disease across age')

# %% [markdown]
# # peak factors causing heart problems

# %% [markdown]
# ### checking for chest pain with a heart disease

# %%
print(hdtrue_df["ChestPainType"])
# Out:
# 1      NAP
# 3      ASY
# 8      ASY
# 11     ATA
# 13     ASY
#       ...
# 912    ASY
# 913     TA
# 914    ASY
# 915    ASY
# 916    ATA
# Name: ChestPainType, Length: 508, dtype: object

# %%
plt.hist(hdtrue_df["ChestPainType"] )
plt.title("for patients with a heart disease")
# Out:
# Text(0.5, 1.0, 'for patients with a heart disease')

# %%
plt.hist(dataset_df["ChestPainType"] )
plt.title("for all patients")
# Out:
# Text(0.5, 1.0, 'for all patients')

# %%
plt.hist(hdfalse_df["ChestPainType"] )
plt.title("without disease")
# Out:
# Text(0.5, 1.0, 'without disease')

# %% [markdown]
# ### Resting BP in patients with a heart disease

# %%
print(hdtrue_df["RestingBP"])
# Out:
# 1      160.0
# 3      138.0
# 8      140.0
# 11     136.0
# 13     140.0
#        ...
# 912    140.0
# 913    110.0
# 914    144.0
# 915    130.0
# 916    130.0
# Name: RestingBP, Length: 508, dtype: float64

# %%
plt.hist(hdtrue_df["RestingBP"], bins =500 )

plt.title("with disease")
# Out:
# Text(0.5, 1.0, 'with disease')

# %%
plt.hist(hdfalse_df["RestingBP"], bins =500 )

plt.title("without disease")
# Out:
# Text(0.5, 1.0, 'without disease')

# %% [markdown]
# ## Fasting BS

# %%
print(hdtrue_df["FastingBS"])
# Out:
# 1      0
# 3      0
# 8      0
# 11     0
# 13     0
#       ..
# 912    0
# 913    0
# 914    1
# 915    0
# 916    0
# Name: FastingBS, Length: 508, dtype: int64

# %%
print(hdtrue_df["FastingBS"].unique())
# Out:
# [0 1]

# %%
print(len(hdtrue_df[hdtrue_df["FastingBS"]==0]))
# Out:
# 338

# %%
len(hdtrue_df[hdtrue_df["FastingBS"]==1])
# Out:
# 170

# %%
plt.pie([(len(hdtrue_df[hdtrue_df["FastingBS"]==0])), (len(hdtrue_df[hdtrue_df["FastingBS"]==1]))])
plt.legend(["FastingBS 0", "FastingBS 1"])
plt.title("Fasting BS distribution with disease")
# Out:
# Text(0.5, 1.0, 'Fasting BS distribution with disease')

# %%
plt.pie([(len(hdfalse_df[hdfalse_df["FastingBS"]==0])), (len(hdfalse_df[hdfalse_df["FastingBS"]==1]))])
plt.legend(["FastingBS 0", "FastingBS 1"])
plt.title("Fasting BS distribution without disease")
# Out:
# Text(0.5, 1.0, 'Fasting BS distribution without disease')

# %%
plt.scatter(hdtrue_df["Age"],hdtrue_df["FastingBS"])
plt.title("FastingBS levels among ages")
plt.xlabel("Age")
plt.ylabel("FastingBS")
# Out:
# Text(0, 0.5, 'FastingBS')

# %% [markdown]
# ### Fasting BS among heart patients who have age more than 50

# %% [markdown]
# ### cholestrol in patients with a heart disease

# %%
plt.hist(hdtrue_df["Cholesterol"], bins= 50 )
# Out:
# (array([152.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   1.,   3.,   3.,
#           2.,   4.,   7.,  14.,  12.,  27.,  31.,  34.,  29.,  24.,  34.,
#          29.,  30.,  17.,  16.,   5.,  11.,   8.,   2.,   1.,   1.,   3.,
#           3.,   0.,   0.,   0.,   0.,   1.,   0.,   1.,   0.,   1.,   1.,
#           0.,   0.,   0.,   0.,   0.,   1.]),
#  array([  0.  ,  12.06,  24.12,  36.18,  48.24,  60.3 ,  72.36,  84.42,
#          96.48, 108.54, 120.6 , 132.66, 144.72, 156.78, 168.84, 180.9 ,
#         192.96, 205.02, 217.08, 229.14, 241.2 , 253.26, 265.32, 277.38,
#         289.44, 301.5 , 313.56, 325.62, 337.68, 349.74, 361.8 , 373.86,
#         385.92, 397.98, 410.04, 422.1 , 434.16, 446.22, 458.28, 470.34,
#         482.4 , 494.46, 506.52, 518.58, 530.64, 542.7 , 554.76, 566.82,
#         578.88, 590.94, 603.  ]),
#  <BarContainer object of 50 artists>)

# %% [markdown]
# # seems like there are a lot of zero values or false value

# %%
cholesterol_df=hdtrue_df[hdtrue_df["Cholesterol"]!=0]
cholesterol_dfwod=hdfalse_df[hdfalse_df["Cholesterol"]!=0]

# %%
plt.hist(cholesterol_df["Cholesterol"], bins =100, linestyle="dashed", ec="red")
plt.title("with disease")
# Out:
# Text(0.5, 1.0, 'with disease')

# %%
plt.hist(cholesterol_dfwod["Cholesterol"], bins =100, linestyle="dashed", ec="red")
plt.title("without disease")
# Out:
# Text(0.5, 1.0, 'without disease')

# %%
plt.scatter(cholesterol_df["Age"],cholesterol_df["Cholesterol"])
plt.title("Cholesterol levels among ages\n(Red line is the upper normal limit for cholesterol level)")
plt.xlabel("Age")
plt.ylabel("Cholesterol")
plt.axhline(200, color="red")

# %% [markdown]
# ## resting ECG

# %%
print(hdtrue_df["RestingECG"])
# Out:
# 1      Normal
# 3      Normal
# 8      Normal
# 11         ST
# 13     Normal
#         ...
# 912    Normal
# 913    Normal
# 914    Normal
# 915    Normal
# 916       LVH
# Name: RestingECG, Length: 508, dtype: object

# %%
print(hdtrue_df["RestingECG"].unique())
# Out:
# ['Normal' 'ST' 'LVH']

# %%
plt.hist(hdtrue_df["RestingECG"])
plt.title("With disease")
# Out:
# Text(0.5, 1.0, 'With disease')

# %%
plt.hist(hdfalse_df["RestingECG"])
plt.title("Without disease")
# Out:
# Text(0.5, 1.0, 'Without disease')

# %%
plt.scatter(hdtrue_df["Age"],hdtrue_df["RestingECG"])
plt.title("RestingECG levels among ages")
plt.xlabel("Age")
plt.ylabel("RestingECG")
# Out:
# Text(0, 0.5, 'RestingECG')

# %% [markdown]
# ## Max HR

# %%
plt.hist(hdtrue_df["MaxHR"], bins =100, linestyle="dashed", ec="red")
plt.title("with disease")
# Out:
# Text(0.5, 1.0, 'with disease')

# %%
plt.hist(hdfalse_df["MaxHR"], bins =100, linestyle="dashed", ec="red")
plt.title("without disease")
# Out:
# Text(0.5, 1.0, 'without disease')

# %%
plt.scatter(hdtrue_df["Age"],hdtrue_df["MaxHR"])
plt.title("MaxHR levels among ages \n red line show normal level for all ages")
plt.xlabel("Age")
plt.ylabel("MaxHR")
x=hdtrue_df["Age"]
y=220-x
plt.plot(x,y, color = "red")

# %% [markdown]
# ## Excercise Angina

# %%
plt.hist(hdtrue_df["ExerciseAngina"], linestyle="dashed", ec="red")
plt.title("with disease")
# Out:
# Text(0.5, 1.0, 'with disease')

# %%
plt.hist(hdfalse_df["ExerciseAngina"], linestyle="dashed", ec="red")
plt.title("without disease")
# Out:
# Text(0.5, 1.0, 'without disease')

# %%
a=len(hdtrue_df[hdtrue_df["ExerciseAngina"]=="N"])
b= len(hdtrue_df[hdtrue_df["ExerciseAngina"]=="Y"])
plt.pie([a, b])
plt.legend(["N","Y"])
plt.title("With disease")
# Out:
# Text(0.5, 1.0, 'With disease')

# %%
a=len(hdfalse_df[hdfalse_df["ExerciseAngina"]=="N"])
b= len(hdfalse_df[hdfalse_df["ExerciseAngina"]=="Y"])
plt.pie([a, b])
plt.legend(["N","Y"])
plt.title("Without disease")
# Out:
# Text(0.5, 1.0, 'Without disease')

# %%
plt.scatter(hdtrue_df["Age"],hdtrue_df["ExerciseAngina"])
plt.title("ExerciseAngina levels among ages")
plt.xlabel("Age")
plt.ylabel("ExerciseAngina")
# Out:
# Text(0, 0.5, 'ExerciseAngina')

# %% [markdown]
# ## Old peak

# %%
plt.hist(hdtrue_df["Oldpeak"], linestyle="dashed", ec="red")
plt.title("with disease")
# Out:
# Text(0.5, 1.0, 'with disease')

# %%
plt.hist(hdfalse_df["Oldpeak"], linestyle="dashed", ec="red")
plt.title("without disease")
# Out:
# Text(0.5, 1.0, 'without disease')

# %%
plt.scatter(hdtrue_df["Age"],hdtrue_df["Oldpeak"])
plt.title("Oldpeak levels among ages \n red line represents the upper normal limit")
plt.xlabel("Age")
plt.ylabel("Oldpeak")
plt.axhline(2, color="red")

# %% [markdown]
# ## Old Peak likely to be above normal when age progresses in Heart Disease Patients

# %% [markdown]
# ## ST slope

# %%
plt.hist(hdtrue_df["ST_Slope"], linestyle="dashed", ec="red")
plt.title("With the disease")
# Out:
# Text(0.5, 1.0, 'With the disease')

# %%
plt.hist(hdfalse_df["ST_Slope"], linestyle="dashed", ec="red")
plt.title("Without the disease")
# Out:
# Text(0.5, 1.0, 'Without the disease')

# %%
plt.scatter(hdtrue_df["Age"],hdtrue_df["ST_Slope"])
plt.title("ST Slope levels among ages")
plt.xlabel("Age")
plt.ylabel("ST Slope")
# Out:
# Text(0, 0.5, 'ST Slope')

# %% [markdown]
# # Model Training

# %%
from sklearn.model_selection import train_test_split

# %%
traindf, testdf = train_test_split(dataset_df, test_size=0.2, random_state=42)

# %% [markdown]
# ## 80 percent of the data used for Training and 20 percent of the data used for Testing

# %%
traindf
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 795   42   M           NAP      120.0          240          1     Normal
# 25    36   M           NAP      130.0          209          0     Normal
# 84    56   M           ASY      150.0          213          1     Normal
# 10    37   F           NAP      130.0          211          0     Normal
# 344   51   M           ASY      120.0            0          1     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 106   48   F           ASY      120.0          254          0         ST
# 270   45   M           ASY      120.0          225          0     Normal
# 860   60   M           ASY      130.0          253          0     Normal
# 435   60   M           ASY      152.0            0          0         ST
# 102   40   F           ASY      150.0          392          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 795    194              N      0.8     Down             0
# 25     178              N      0.0       Up             0
# 84     125              Y      1.0     Flat             1
# 10     142              N      0.0       Up             0
# 344    104              N      0.0     Flat             1
# ..     ...            ...      ...      ...           ...
# 106    110              N      0.0       Up             0
# 270    140              N      0.0       Up             0
# 860    144              Y      1.4       Up             1
# 435    118              Y      0.0       Up             0
# 102    130              N      2.0     Flat             1
#
# [734 rows x 12 columns]

# %%
testdf
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 668   63   F           ATA      140.0          195          0     Normal
# 30    53   M           NAP      145.0          518          0     Normal
# 377   65   M           ASY      160.0            0          1         ST
# 535   56   M           ASY      130.0            0          0        LVH
# 807   54   M           ATA      108.0          309          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 211   50   F           NAP      140.0          288          0     Normal
# 745   63   F           ASY      108.0          269          0     Normal
# 584   64   M           ASY      141.0          244          1         ST
# 878   49   M           ATA      130.0          266          0     Normal
# 451   64   M           ASY      144.0            0          0         ST
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 668    179              N      0.0       Up             0
# 30     130              N      0.0     Flat             1
# 377    122              N      1.2     Flat             1
# 535    122              Y      1.0     Flat             1
# 807    156              N      0.0       Up             0
# ..     ...            ...      ...      ...           ...
# 211    140              Y      0.0     Flat             1
# 745    169              Y      1.8     Flat             1
# 584    116              Y      1.5     Flat             1
# 878    171              N      0.6       Up             0
# 451    122              Y      1.0     Flat             1
#
# [184 rows x 12 columns]

# %%
inputdf=traindf[inputcol].copy()
targetdf=traindf[targetcol].copy()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[727], line 1
# ----> 1 inputdf=traindf[inputcol].copy()
#       2 targetdf=traindf[targetcol].copy()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:6070, in Index._get_indexer_strict(self, key, axis_name)
#    6067 else:
#    6068     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6070 self._raise_if_missing(keyarr, indexer, axis_name)
#    6072 keyarr = self.take(indexer)
#    6073 if isinstance(key, Index):
#    6074     # GH 42790 - Preserve name from an Index
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:6133, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6130     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6132 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6133 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['Sex_F', 'Sex_M', 'ChestPainType_ASY', 'ChestPainType_ATA', 'ChestPainType_NAP', 'ChestPainType_TA', 'RestingECG_LVH', 'RestingECG_Normal', 'RestingECG_ST', 'ExerciseAngina_N', 'ExerciseAngina_Y', 'ST_Slope_Down', 'ST_Slope_Flat'] not in index"

# %%
inputdf

# %%
targetdf

# %%
inputcol=list(traindf.columns)[0:-1]
targetcol='HeartDisease'

# %%
print(inputcol)

# %% [markdown]
# ## Inputs and Target

# %% [markdown]
# ## As we will be carrying out scaling operations with the data set, making a copy of the data frame in a seperate data frame

# %% [markdown]
# ## the original dataset had a lot of a zero values in the cholesterol section

# %%
cholesteroltrue=dataset_df[dataset_df["Cholesterol"]!=0]

# %%
cholesteroltrue
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA      140.0          289          0     Normal
# 1     49   F           NAP      160.0          180          0     Normal
# 2     37   M           ATA      130.0          283          0         ST
# 3     48   F           ASY      138.0          214          0     Normal
# 4     54   M           NAP      150.0          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA      110.0          264          0     Normal
# 914   68   M           ASY      144.0          193          1     Normal
# 915   57   M           ASY      130.0          131          0     Normal
# 916   57   F           ATA      130.0          236          0        LVH
# 917   38   M           NAP      138.0          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0      172              N      0.0       Up             0
# 1      156              N      1.0     Flat             1
# 2       98              N      0.0       Up             0
# 3      108              Y      1.5     Flat             1
# 4      122              N      0.0       Up             0
# ..     ...            ...      ...      ...           ...
# 913    132              N      1.2     Flat             1
# 914    141              N      3.4     Flat             1
# 915    115              Y      1.2     Flat             1
# 916    174              N      0.0     Flat             1
# 917    173              N      0.0       Up             0
#
# [746 rows x 12 columns]

# %% [markdown]
# ## Replacing the zero values with the mean

# %%
mean= cholesteroltrue.Cholesterol.mean()

# %%
mean
# Out:
# 244.6353887399464

# %%
traindf['Cholesterol'].replace(to_replace = 0, value = mean, inplace=True)

# %%
traindf
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 795   42   M           NAP      120.0   240.000000          1     Normal
# 25    36   M           NAP      130.0   209.000000          0     Normal
# 84    56   M           ASY      150.0   213.000000          1     Normal
# 10    37   F           NAP      130.0   211.000000          0     Normal
# 344   51   M           ASY      120.0   244.635389          1     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 106   48   F           ASY      120.0   254.000000          0         ST
# 270   45   M           ASY      120.0   225.000000          0     Normal
# 860   60   M           ASY      130.0   253.000000          0     Normal
# 435   60   M           ASY      152.0   244.635389          0         ST
# 102   40   F           ASY      150.0   392.000000          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 795    194              N      0.8     Down             0
# 25     178              N      0.0       Up             0
# 84     125              Y      1.0     Flat             1
# 10     142              N      0.0       Up             0
# 344    104              N      0.0     Flat             1
# ..     ...            ...      ...      ...           ...
# 106    110              N      0.0       Up             0
# 270    140              N      0.0       Up             0
# 860    144              Y      1.4       Up             1
# 435    118              Y      0.0       Up             0
# 102    130              N      2.0     Flat             1
#
# [734 rows x 12 columns]

# %%
traindf[traindf['Cholesterol']== mean]
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 344   51   M           ASY      120.0   244.635389          1     Normal
# 398   52   M           ASY      165.0   244.635389          1     Normal
# 300   60   M           ASY      160.0   244.635389          1     Normal
# 326   45   M           NAP      110.0   244.635389          0     Normal
# 430   57   M           ASY      128.0   244.635389          1         ST
# ..   ...  ..           ...        ...          ...        ...        ...
# 372   63   M           ASY      185.0   244.635389          0     Normal
# 458   61   M           ASY      134.0   244.635389          1         ST
# 330   60   M           NAP      115.0   244.635389          1     Normal
# 466   55   M           NAP      120.0   244.635389          0         ST
# 435   60   M           ASY      152.0   244.635389          0         ST
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 344    104              N      0.0     Flat             1
# 398    122              Y      1.0       Up             1
# 300    149              N      0.4     Flat             1
# 326    138              N     -0.1       Up             0
# 430    148              Y      1.0     Flat             1
# ..     ...            ...      ...      ...           ...
# 372     98              Y      0.0       Up             1
# 458     86              N      1.5     Flat             1
# 330    143              N      2.4       Up             1
# 466    125              Y      2.5     Flat             1
# 435    118              Y      0.0       Up             0
#
# [137 rows x 12 columns]

# %% [markdown]
# ## Numerical and Categorical Columns

# %%
numericcol = inputdf.select_dtypes(include=np.number).columns.tolist()
categoricalcol = inputdf.select_dtypes('object').columns.tolist()

# %%
numericcol
# Out:
# ['Age',
#  'RestingBP',
#  'Cholesterol',
#  'FastingBS',
#  'MaxHR',
#  'Oldpeak',
#  'HeartDisease',
#  'Sex_F',
#  'Sex_M',
#  'ChestPainType_ASY',
#  'ChestPainType_ATA',
#  'ChestPainType_NAP',
#  'ChestPainType_TA',
#  'RestingECG_LVH',
#  'RestingECG_Normal',
#  'RestingECG_ST',
#  'ExerciseAngina_N',
#  'ExerciseAngina_Y',
#  'ST_Slope_Down',
#  'ST_Slope_Flat']

# %%
categoricalcol
# Out:
# ['Sex', 'ChestPainType', 'RestingECG', 'ExerciseAngina', 'ST_Slope']

# %% [markdown]
# ## Missing values could have been filled with the imputer also

# %%
from sklearn.impute import SimpleImputer

# %%
imputer = SimpleImputer(strategy = 'mean')

# %%
traindf[numericcol].isna().sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[740], line 1
# ----> 1 traindf[numericcol].isna().sum()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:6070, in Index._get_indexer_strict(self, key, axis_name)
#    6067 else:
#    6068     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6070 self._raise_if_missing(keyarr, indexer, axis_name)
#    6072 keyarr = self.take(indexer)
#    6073 if isinstance(key, Index):
#    6074     # GH 42790 - Preserve name from an Index
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:6133, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6130     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6132 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6133 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['Sex_F', 'Sex_M', 'ChestPainType_ASY', 'ChestPainType_ATA', 'ChestPainType_NAP', 'ChestPainType_TA', 'RestingECG_LVH', 'RestingECG_Normal', 'RestingECG_ST', 'ExerciseAngina_N', 'ExerciseAngina_Y', 'ST_Slope_Down', 'ST_Slope_Flat'] not in index"

# %% [markdown]
# ## Since there are no missing values, we can proceed ahead

# %% [markdown]
# ## We will now scale the values within 1 and 0

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
scaler.fit(traindf[numeric_cols])

# %%
traindf

# %%
scaler.data_min_

# %%
scaler.data_max_

# %%
traindf[numericcol] = scaler.transform(traindf[numericcol])

# %% [markdown]
# ## All values scaled between 0 and 1 now

# %%
traindf

# %%
inputdf[categoricalcol].nunique()

# %%
from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# ## Dividing the different values of categorical columns as seperate columns

# %%
encoder = OneHotEncoder(sparse=False, handle_unknown='ignore', sparse_output=False)

# %%
encoder.fit(dataset_df[categorical_cols])

# %%
encoded_cols = list(encoder.get_feature_names_out(categorical_cols))

# %%
encoded_cols

# %%
traindf[encoded_cols] = encoder.transform(traindf[categorical_cols])

# %%
testdf[encoded_cols] = encoder.transform(testdf[categorical_cols])

# %%
traindf

# %%
inputdf

# %%
targetdf

# %% [markdown]
# ## training the logistical regression model

# %%
model = LogisticRegression(solver='liblinear')

# %%
model.fit(traindf[numeric_cols + encoded_cols], targetdf)

# %%
model.coef_

# %%
model.intercept_

# %%
X_train = inputdf[numericcol + encoded_cols]
